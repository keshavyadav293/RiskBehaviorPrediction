# %%
# Import Necessary Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
# Import the datset 
data = pd.read_csv("addiction_population_data.csv")
data.head(10)
# Out:
#    id              name  age  gender                country             city  \
# 0   1     Michael Bates   66   Other                  Yemen      Martinmouth
# 1   2    Brian Thompson   29    Male           Saudi Arabia      Harperhaven
# 2   3     Steven Little   75    Male                   Togo         Chanport
# 3   4   Michael Mathews   35   Other                   Togo       North Cory
# 4   5  Nicholas Sanchez   38  Female                Morocco       Danielberg
# 5   6    Carrie Sellers   17    Male                Belgium      West Arthur
# 6   7  Jessica Riley MD   36    Male  Saint Kitts and Nevis  Christopherstad
# 7   8    Walter Tran MD   67    Male      Equatorial Guinea        Silvaberg
# 8   9    Melanie Walker   16   Other           Burkina Faso       Brandystad
# 9  10      Carl Mathews   44    Male               Barbados      Roseborough
#
#   education_level employment_status  annual_income_usd     marital_status  \
# 0       Secondary           Student              45595            Married
# 1         Primary     Self-Employed             145842             Single
# 2    Postgraduate        Unemployed             162480             Single
# 3      University        Unemployed              16023  In a relationship
# 4         College     Self-Employed              62933  In a relationship
# 5       Secondary          Employed             178640             Single
# 6         College     Self-Employed              20491            Widowed
# 7         College        Unemployed              11275             Single
# 8    Postgraduate           Retired              85495           Divorced
# 9      University     Self-Employed             192822             Single
#
#    ...  attempts_to_quit_smoking  attempts_to_quit_drinking  \
# 0  ...                         6                          2
# 1  ...                         1                          6
# 2  ...                         9                          9
# 3  ...                         5                          7
# 4  ...                         4                          7
# 5  ...                         2                          3
# 6  ...                         4                          9
# 7  ...                         9                          1
# 8  ...                         6                          5
# 9  ...                         2                          2
#
#    has_health_issues  mental_health_status  exercise_frequency  diet_quality  \
# 0               True                  Good               Daily       Average
# 1              False                  Poor              Weekly          Good
# 2               True                  Good               Never          Good
# 3              False               Average               Daily          Good
# 4               True                  Poor              Weekly          Good
# 5               True                  Good               Never       Average
# 6              False                  Good              Weekly          Good
# 7               True               Average              Weekly          Good
# 8              False                  Good              Weekly          Good
# 9              False               Average              Weekly          Poor
#
#    sleep_hours   bmi social_support therapy_history
# 0          5.6  22.4            NaN         Current
# 1          6.7  24.1       Moderate             NaN
# 2          6.2  22.2           Weak             NaN
# 3          7.2  25.5       Moderate         Current
# 4          8.5  31.2           Weak            Past
# 5          6.4  29.3           Weak            Past
# 6          4.5  32.6       Moderate            Past
# 7          3.6  24.6           Weak             NaN
# 8          4.6  24.6            NaN             NaN
# 9          4.5  26.0         Strong         Current
#
# [10 rows x 25 columns]

# %%
# Size of Dataset
data.size
# Out:
# 75000

# %%
# Rows and Columns in Dataset
data.shape
# Out:
# (3000, 25)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         3000 non-null   int64
#  1   name                       3000 non-null   object
#  2   age                        3000 non-null   int64
#  3   gender                     3000 non-null   object
#  4   country                    3000 non-null   object
#  5   city                       3000 non-null   object
#  6   education_level            2580 non-null   object
#  7   employment_status          3000 non-null   object
#  8   annual_income_usd          3000 non-null   int64
#  9   marital_status             3000 non-null   object
#  10  children_count             3000 non-null   int64
#  11  smokes_per_day             3000 non-null   int64
#  12  drinks_per_week            3000 non-null   int64
#  13  age_started_smoking        3000 non-null   int64
#  14  age_started_drinking       3000 non-null   int64
#  15  attempts_to_quit_smoking   3000 non-null   int64
#  16  attempts_to_quit_drinking  3000 non-null   int64
#  17  has_health_issues          3000 non-null   bool
#  18  mental_health_status       3000 non-null   object
#  19  exercise_frequency         3000 non-null   object
#  20  diet_quality               3000 non-null   object
#  21  sleep_hours                3000 non-null   float64
#  22  bmi                        3000 non-null   float64
#  23  social_support             2247 non-null   object
#  24  therapy_history            1986 non-null   object
# dtypes: bool(1), float64(2), int64(10), object(12)
# memory usage: 565.6+ KB

# %%
# Columns in Datset
data.columns.to_list()
# Out:
# ['id',
#  'name',
#  'age',
#  'gender',
#  'country',
#  'city',
#  'education_level',
#  'employment_status',
#  'annual_income_usd',
#  'marital_status',
#  'children_count',
#  'smokes_per_day',
#  'drinks_per_week',
#  'age_started_smoking',
#  'age_started_drinking',
#  'attempts_to_quit_smoking',
#  'attempts_to_quit_drinking',
#  'has_health_issues',
#  'mental_health_status',
#  'exercise_frequency',
#  'diet_quality',
#  'sleep_hours',
#  'bmi',
#  'social_support',
#  'therapy_history']

# %%
# Clean Column Names
data.columns.str.strip().str.lower().str.replace(' ', '_')
# Out:
# Index(['id', 'name', 'age', 'gender', 'country', 'city', 'education_level',
#        'employment_status', 'annual_income_usd', 'marital_status',
#        'children_count', 'smokes_per_day', 'drinks_per_week',
#        'age_started_smoking', 'age_started_drinking',
#        'attempts_to_quit_smoking', 'attempts_to_quit_drinking',
#        'has_health_issues', 'mental_health_status', 'exercise_frequency',
#        'diet_quality', 'sleep_hours', 'bmi', 'social_support',
#        'therapy_history'],
#       dtype='object')

# %%
# Describing the dataset using heatmap
data.describe().style.background_gradient(cmap = 'viridis')
# Out:
# <style type="text/css">
# #T_9a6fb_row0_col0, #T_9a6fb_row0_col1, #T_9a6fb_row0_col3, #T_9a6fb_row0_col4, #T_9a6fb_row0_col5, #T_9a6fb_row0_col6, #T_9a6fb_row0_col7, #T_9a6fb_row0_col8, #T_9a6fb_row0_col9, #T_9a6fb_row0_col10, #T_9a6fb_row0_col11, #T_9a6fb_row7_col0, #T_9a6fb_row7_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_9a6fb_row0_col2, #T_9a6fb_row7_col11 {
#   background-color: #450559;
#   color: #f1f1f1;
# }
# #T_9a6fb_row1_col0, #T_9a6fb_row5_col0 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_9a6fb_row1_col1, #T_9a6fb_row5_col1, #T_9a6fb_row7_col6, #T_9a6fb_row7_col7 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_9a6fb_row1_col2 {
#   background-color: #218f8d;
#   color: #f1f1f1;
# }
# #T_9a6fb_row1_col3, #T_9a6fb_row1_col4, #T_9a6fb_row1_col5, #T_9a6fb_row1_col8, #T_9a6fb_row1_col9, #T_9a6fb_row1_col10, #T_9a6fb_row2_col1, #T_9a6fb_row2_col3, #T_9a6fb_row2_col4, #T_9a6fb_row2_col5, #T_9a6fb_row2_col6, #T_9a6fb_row2_col7, #T_9a6fb_row2_col8, #T_9a6fb_row2_col9, #T_9a6fb_row2_col10, #T_9a6fb_row2_col11, #T_9a6fb_row3_col0, #T_9a6fb_row3_col1, #T_9a6fb_row3_col2, #T_9a6fb_row3_col3, #T_9a6fb_row3_col4, #T_9a6fb_row3_col5, #T_9a6fb_row3_col6, #T_9a6fb_row3_col7, #T_9a6fb_row3_col8, #T_9a6fb_row3_col9, #T_9a6fb_row3_col10, #T_9a6fb_row3_col11, #T_9a6fb_row4_col3, #T_9a6fb_row4_col4, #T_9a6fb_row4_col5, #T_9a6fb_row4_col6, #T_9a6fb_row4_col7, #T_9a6fb_row4_col8, #T_9a6fb_row4_col9, #T_9a6fb_row4_col10, #T_9a6fb_row5_col3, #T_9a6fb_row5_col4, #T_9a6fb_row5_col5, #T_9a6fb_row5_col8, #T_9a6fb_row5_col9, #T_9a6fb_row5_col10, #T_9a6fb_row6_col3, #T_9a6fb_row6_col4, #T_9a6fb_row6_col5, #T_9a6fb_row6_col8, #T_9a6fb_row6_col9, #T_9a6fb_row6_col10, #T_9a6fb_row7_col3, #T_9a6fb_row7_col8, #T_9a6fb_row7_col9, #T_9a6fb_row7_col10 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_9a6fb_row1_col6, #T_9a6fb_row1_col7, #T_9a6fb_row1_col11, #T_9a6fb_row4_col1, #T_9a6fb_row4_col11, #T_9a6fb_row5_col6, #T_9a6fb_row5_col7, #T_9a6fb_row5_col11, #T_9a6fb_row6_col6, #T_9a6fb_row6_col7, #T_9a6fb_row6_col11, #T_9a6fb_row7_col4, #T_9a6fb_row7_col5 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_9a6fb_row2_col0 {
#   background-color: #365c8d;
#   color: #f1f1f1;
# }
# #T_9a6fb_row2_col2 {
#   background-color: #375b8d;
#   color: #f1f1f1;
# }
# #T_9a6fb_row4_col0 {
#   background-color: #3b528b;
#   color: #f1f1f1;
# }
# #T_9a6fb_row4_col2 {
#   background-color: #3c508b;
#   color: #f1f1f1;
# }
# #T_9a6fb_row5_col2 {
#   background-color: #218e8d;
#   color: #f1f1f1;
# }
# #T_9a6fb_row6_col0 {
#   background-color: #5ec962;
#   color: #000000;
# }
# #T_9a6fb_row6_col1 {
#   background-color: #46075a;
#   color: #f1f1f1;
# }
# #T_9a6fb_row6_col2 {
#   background-color: #5ac864;
#   color: #000000;
# }
# #T_9a6fb_row7_col1 {
#   background-color: #46085c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9a6fb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a6fb_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_9a6fb_level0_col1" class="col_heading level0 col1" >age</th>
#       <th id="T_9a6fb_level0_col2" class="col_heading level0 col2" >annual_income_usd</th>
#       <th id="T_9a6fb_level0_col3" class="col_heading level0 col3" >children_count</th>
#       <th id="T_9a6fb_level0_col4" class="col_heading level0 col4" >smokes_per_day</th>
#       <th id="T_9a6fb_level0_col5" class="col_heading level0 col5" >drinks_per_week</th>
#       <th id="T_9a6fb_level0_col6" class="col_heading level0 col6" >age_started_smoking</th>
#       <th id="T_9a6fb_level0_col7" class="col_heading level0 col7" >age_started_drinking</th>
#       <th id="T_9a6fb_level0_col8" class="col_heading level0 col8" >attempts_to_quit_smoking</th>
#       <th id="T_9a6fb_level0_col9" class="col_heading level0 col9" >attempts_to_quit_drinking</th>
#       <th id="T_9a6fb_level0_col10" class="col_heading level0 col10" >sleep_hours</th>
#       <th id="T_9a6fb_level0_col11" class="col_heading level0 col11" >bmi</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a6fb_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_9a6fb_row0_col0" class="data row0 col0" >3000.000000</td>
#       <td id="T_9a6fb_row0_col1" class="data row0 col1" >3000.000000</td>
#       <td id="T_9a6fb_row0_col2" class="data row0 col2" >3000.000000</td>
#       <td id="T_9a6fb_row0_col3" class="data row0 col3" >3000.000000</td>
#       <td id="T_9a6fb_row0_col4" class="data row0 col4" >3000.000000</td>
#       <td id="T_9a6fb_row0_col5" class="data row0 col5" >3000.000000</td>
#       <td id="T_9a6fb_row0_col6" class="data row0 col6" >3000.000000</td>
#       <td id="T_9a6fb_row0_col7" class="data row0 col7" >3000.000000</td>
#       <td id="T_9a6fb_row0_col8" class="data row0 col8" >3000.000000</td>
#       <td id="T_9a6fb_row0_col9" class="data row0 col9" >3000.000000</td>
#       <td id="T_9a6fb_row0_col10" class="data row0 col10" >3000.000000</td>
#       <td id="T_9a6fb_row0_col11" class="data row0 col11" >3000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9a6fb_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_9a6fb_row1_col0" class="data row1 col0" >1500.500000</td>
#       <td id="T_9a6fb_row1_col1" class="data row1 col1" >46.654333</td>
#       <td id="T_9a6fb_row1_col2" class="data row1 col2" >98904.178000</td>
#       <td id="T_9a6fb_row1_col3" class="data row1 col3" >2.453667</td>
#       <td id="T_9a6fb_row1_col4" class="data row1 col4" >10.034000</td>
#       <td id="T_9a6fb_row1_col5" class="data row1 col5" >5.002333</td>
#       <td id="T_9a6fb_row1_col6" class="data row1 col6" >24.365667</td>
#       <td id="T_9a6fb_row1_col7" class="data row1 col7" >24.525333</td>
#       <td id="T_9a6fb_row1_col8" class="data row1 col8" >4.440333</td>
#       <td id="T_9a6fb_row1_col9" class="data row1 col9" >4.542000</td>
#       <td id="T_9a6fb_row1_col10" class="data row1 col10" >6.470400</td>
#       <td id="T_9a6fb_row1_col11" class="data row1 col11" >25.170133</td>
#     </tr>
#     <tr>
#       <th id="T_9a6fb_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_9a6fb_row2_col0" class="data row2 col0" >866.169729</td>
#       <td id="T_9a6fb_row2_col1" class="data row2 col1" >18.740880</td>
#       <td id="T_9a6fb_row2_col2" class="data row2 col2" >57288.035963</td>
#       <td id="T_9a6fb_row2_col3" class="data row2 col3" >1.704354</td>
#       <td id="T_9a6fb_row2_col4" class="data row2 col4" >3.108386</td>
#       <td id="T_9a6fb_row2_col5" class="data row2 col5" >2.214037</td>
#       <td id="T_9a6fb_row2_col6" class="data row2 col6" >8.707309</td>
#       <td id="T_9a6fb_row2_col7" class="data row2 col7" >8.679121</td>
#       <td id="T_9a6fb_row2_col8" class="data row2 col8" >2.835334</td>
#       <td id="T_9a6fb_row2_col9" class="data row2 col9" >2.866992</td>
#       <td id="T_9a6fb_row2_col10" class="data row2 col10" >1.495878</td>
#       <td id="T_9a6fb_row2_col11" class="data row2 col11" >5.013345</td>
#     </tr>
#     <tr>
#       <th id="T_9a6fb_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_9a6fb_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_9a6fb_row3_col1" class="data row3 col1" >15.000000</td>
#       <td id="T_9a6fb_row3_col2" class="data row3 col2" >560.000000</td>
#       <td id="T_9a6fb_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_9a6fb_row3_col4" class="data row3 col4" >2.000000</td>
#       <td id="T_9a6fb_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_9a6fb_row3_col6" class="data row3 col6" >10.000000</td>
#       <td id="T_9a6fb_row3_col7" class="data row3 col7" >10.000000</td>
#       <td id="T_9a6fb_row3_col8" class="data row3 col8" >0.000000</td>
#       <td id="T_9a6fb_row3_col9" class="data row3 col9" >0.000000</td>
#       <td id="T_9a6fb_row3_col10" class="data row3 col10" >1.500000</td>
#       <td id="T_9a6fb_row3_col11" class="data row3 col11" >9.100000</td>
#     </tr>
#     <tr>
#       <th id="T_9a6fb_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_9a6fb_row4_col0" class="data row4 col0" >750.750000</td>
#       <td id="T_9a6fb_row4_

# %% [markdown]
# MISSING VALUES
# ===

# %%
# Any Null Values in the Dataset
data.isnull()
# Out:
#          id   name    age  gender  country   city  education_level  \
# 0     False  False  False   False    False  False            False
# 1     False  False  False   False    False  False            False
# 2     False  False  False   False    False  False            False
# 3     False  False  False   False    False  False            False
# 4     False  False  False   False    False  False            False
# ...     ...    ...    ...     ...      ...    ...              ...
# 2995  False  False  False   False    False  False            False
# 2996  False  False  False   False    False  False            False
# 2997  False  False  False   False    False  False            False
# 2998  False  False  False   False    False  False            False
# 2999  False  False  False   False    False  False             True
#
#       employment_status  annual_income_usd  marital_status  ...  \
# 0                 False              False           False  ...
# 1                 False              False           False  ...
# 2                 False              False           False  ...
# 3                 False              False           False  ...
# 4                 False              False           False  ...
# ...                 ...                ...             ...  ...
# 2995              False              False           False  ...
# 2996              False              False           False  ...
# 2997              False              False           False  ...
# 2998              False              False           False  ...
# 2999              False              False           False  ...
#
#       attempts_to_quit_smoking  attempts_to_quit_drinking  has_health_issues  \
# 0                        False                      False              False
# 1                        False                      False              False
# 2                        False                      False              False
# 3                        False                      False              False
# 4                        False                      False              False
# ...                        ...                        ...                ...
# 2995                     False                      False              False
# 2996                     False                      False              False
# 2997                     False                      False              False
# 2998                     False                      False              False
# 2999                     False                      False              False
#
#       mental_health_status  exercise_frequency  diet_quality  sleep_hours  \
# 0                    False               False         False        False
# 1                    False               False         False        False
# 2                    False               False         False        False
# 3                    False               False         False        False
# 4                    False               False         False        False
# ...                    ...                 ...           ...          ...
# 2995                 False               False         False        False
# 2996                 False               False         False        False
# 2997                 False               False         False        False
# 2998                 False               False         False        False
# 2999                 False               False         False        False
#
#         bmi  social_support  therapy_history
# 0     False            True            False
# 1     False           False             True
# 2     False           False             True
# 3     False           False            False
# 4     False           False            False
# ...     ...             ...              ...
# 2995  False           False            False
# 2996  False           False            False
# 2997  False           False            False
# 2998  False            True            False
# 2999  False           False            False
#
# [3000 rows x 25 columns]

# %%
# Count of null values are present in the dataset
data.isnull().sum()
# Out:
# id                              0
# name                            0
# age                             0
# gender                          0
# country                         0
# city                            0
# education_level               420
# employment_status               0
# annual_income_usd               0
# marital_status                  0
# children_count                  0
# smokes_per_day                  0
# drinks_per_week                 0
# age_started_smoking             0
# age_started_drinking            0
# attempts_to_quit_smoking        0
# attempts_to_quit_drinking       0
# has_health_issues               0
# mental_health_status            0
# exercise_frequency              0
# diet_quality                    0
# sleep_hours                     0
# bmi                             0
# social_support                753
# therapy_history              1014
# dtype: int64

# %%
# % of missing values per column
data.isnull().mean() * 100
# Out:
# id                            0.0
# name                          0.0
# age                           0.0
# gender                        0.0
# country                       0.0
# city                          0.0
# education_level              14.0
# employment_status             0.0
# annual_income_usd             0.0
# marital_status                0.0
# children_count                0.0
# smokes_per_day                0.0
# drinks_per_week               0.0
# age_started_smoking           0.0
# age_started_drinking          0.0
# attempts_to_quit_smoking      0.0
# attempts_to_quit_drinking     0.0
# has_health_issues             0.0
# mental_health_status          0.0
# exercise_frequency            0.0
# diet_quality                  0.0
# sleep_hours                   0.0
# bmi                           0.0
# social_support               25.1
# therapy_history              33.8
# dtype: float64

# %%
# Check for null values
null_counts = data.isnull().sum()
null_counts[null_counts > 0]
# Out:
# education_level     420
# social_support      753
# therapy_history    1014
# dtype: int64

# %%
# Handling Missing Values :- Fill with Most Frequent Value (Mode)
data['education_level'].fillna(data['education_level'].mode()[0], inplace=True)
data['social_support'].fillna(data['social_support'].mode()[0], inplace=True)
data['therapy_history'].fillna(data['therapy_history'].mode()[0], inplace=True)

# %% [markdown]
# VISUALIZATION
# ====

# %% [markdown]
# 1. Age Distribution (Violin Plot)

# %%
plt.figure(figsize = (15, 6))
sns.violinplot(y = data['age'], color = "#83D4DA")
plt.title('AGE DISTRIBUTION')
plt.xlabel('Range')
plt.ylabel('Frequency')
plt.grid(False)
plt.show()

# %% [markdown]
# 2. Gender Distribution (Bar Chart)

# %%
plt.figure(figsize = (15, 6))
sorted = data['gender'].value_counts().sort_values().index
a = sns.countplot(x = data['gender'], hue = data['gender'], order = sorted, palette = 'viridis')
for container in a.containers:
    a.bar_label(container)
plt.title('GENDER DISTRIBUTION')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.grid(False)
plt.show()

# %% [markdown]
# 3. Education Level by Gender (Clustered Column Chart)

# %%
plt.figure(figsize = (15, 6))
sns.countplot(x = 'education_level', hue = 'gender', data = data, palette = 'magma')
plt.title('Education Level Distribution by Gender')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# 4. Employment Status by Education Level (Clustered Column Chart)

# %%
plt.figure(figsize = (15, 6))
sns.countplot(x = 'employment_status', hue = 'education_level', data = data, palette = 'magma')
plt.title('Employment Status Distribution by Education Level')
plt.xlabel('Employment Status')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# 5. Income Distribution (Pie Chart)

# %%
# Define income brackets
bins = [0, 20000, 40000, 60000, 80000, 100000, float('inf')]
labels = ['<20k', '20k-40k', '40k-60k', '60k-80k', '80k-100k', '>100k']

# Create income bracket column
data['income_bracket'] = pd.cut(data['annual_income_usd'], bins = bins, labels = labels, right = False)

# Count number of people 
bracket_counts = data['income_bracket'].value_counts().sort_index()

plt.figure(figsize=(15, 6))
plt.pie(bracket_counts, labels = bracket_counts.index, autopct = '%1.1f%%')
plt.title('Income Distribution')
plt.axis('equal')
plt.show()

# %% [markdown]
# 6. Marital Status (Donut Chart)

# %%
Col_J = data['marital_status'].value_counts()

plt.figure(figsize = (15, 6))
plt.pie(Col_J, labels = Col_J.index, autopct = '%1.1f%%', wedgeprops={'width': 0.5})
plt.title('Marital Status Distribution')
plt.axis('equal') 
plt.show()

# %% [markdown]
# 7. Children Count Distribution (Pie Chart)

# %%
# Create a new column for children group
data['children_group'] = pd.cut(data['children_count'], bins = [-1, 2, 4, float('inf')], labels = ['0-2 children', '3-4 children', '5+ children'])

# Count the number of people in each group
Col_K = data['children_group'].value_counts().sort_index()

# Plot pie chart
plt.figure(figsize=(15, 6))
plt.pie(Col_K, labels = Col_K.index, autopct = '%1.1f%%', startangle = 50)
plt.title('Distribution of Number of Children')
plt.axis('equal')
plt.show()

# %% [markdown]
# 8. Cigarettes Smoked per Day (Histogram)

# %%
plt.figure(figsize = (15, 6))
sns.histplot(data['smokes_per_day'], bins = 20, kde = True, color= 'salmon')
plt.title('Cigarettes Smoked per Day')
plt.xlabel('Cigarettes per Day')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 9. Drinks Consumed per Week (Histogram)

# %%
plt.figure(figsize=(15, 6))
sns.histplot(data['drinks_per_week'], bins = 20, kde = True, color = 'lightgreen')
plt.title('Drinks Consumed per Week')
plt.xlabel('Drinks per Week')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 10. Age Started Smoking by Gender (Bar Chart)

# %%
plt.figure(figsize = (15, 6))
sns.countplot(x = 'age_started_smoking', hue = 'gender', data = data, palette = 'magma')
plt.title('Distribution of Age When People Started Smoking by Gender')
plt.xlabel('Age Started Smoking')
plt.ylabel('Number of People')
plt.show()

# %% [markdown]
# 11. Age Started Drinking by Gender

# %%
plt.figure(figsize = (15, 6))
sns.countplot(x = 'age_started_drinking', hue = 'gender', data = data, palette = 'Paired')
plt.title('Distribution of Age When People Started Smoking by Gender')
plt.xlabel('Age Started Drinking')
plt.ylabel('Number of People')
plt.show()

# %% [markdown]
# 12. Count of Attempts to Quit Smoking (Bubble Chart)

# %%
Col_P = data['attempts_to_quit_smoking'].value_counts().sort_index()
plt.figure(figsize = (15, 6))
plt.scatter(x = Col_P.index, y = Col_P.values, s = Col_P.values * 20, marker='x', color = 'red')
plt.title('Bubble Chart: Attempts to Quit Smoking')
plt.xlabel('Number of Attempts')
plt.ylabel('Number of People')
plt.grid(True, linestyle='--', alpha = 0.5)
plt.show()

# %% [markdown]
# 13. Count of Attempts to Quit Drinking (Lollipop Chart)

# %%
Col_Q = data['attempts_to_quit_drinking'].value_counts().sort_index()

plt.figure(figsize=(15, 6))
(markerline, stemlines, baseline) = plt.stem(Col_Q.index, Col_Q.values, linefmt='gray', markerfmt='o', basefmt=" ")
plt.setp(markerline, color='orange', markersize=10)
plt.setp(stemlines, linewidth=2)
plt.title('Lollipop Chart: Attempts to Quit Drinking')
plt.xlabel('Number of Attempts')
plt.ylabel('Number of People')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# 14. Smoking vs Health Issues (Boxplots)

# %%
plt.figure(figsize=(15, 6))
sns.boxplot(data=data, x='has_health_issues', y='smokes_per_day', hue = 'has_health_issues', palette='Set2')
plt.title('Smoking per Day vs Health Issues')
plt.show()

# %% [markdown]
# 15. Drinking vs Health Issues (Boxplots)

# %%
plt.figure(figsize=(14, 6))
sns.boxplot(data=data, x='has_health_issues', y='drinks_per_week', hue = 'has_health_issues', palette='magma')
plt.title('Drinks per Week vs Health Issues')
plt.show()

# %% [markdown]
# 16. Avg smoking & drinking by mental health status (Bar plots)

# %%
avg_behavior = data.groupby('mental_health_status')[['smokes_per_day', 'drinks_per_week']].mean().reset_index()

fig, axs = plt.subplots(1, 2, figsize=(14, 5))
sns.barplot(data=avg_behavior, x='mental_health_status', y='smokes_per_day', hue='mental_health_status', ax=axs[0], palette='muted')
axs[0].set_title('Average Cigarettes per Day by Mental Health')
sns.barplot(data=avg_behavior, x='mental_health_status', y='drinks_per_week', hue='mental_health_status', ax=axs[1], palette='muted')
axs[1].set_title('Average Drinks per Week by Mental Health')
plt.tight_layout()
plt.show()

# %% [markdown]
# 17. Exercise Frequency Distribution (Pie Chart)

# %%
Col_U = data['exercise_frequency'].value_counts().sort_index()

plt.figure(figsize=(15, 6))
plt.pie(Col_U, labels = Col_U.index, autopct = '%1.1f%%', colors = plt.cm.Pastel1.colors)
plt.title('Exercise Frequency')
plt.axis('equal')
plt.show()

# %% [markdown]
# 18. Diet Quality (Donut Chart)

# %%
Col_U = data['diet_quality'].value_counts().sort_index()

plt.figure(figsize=(15, 6))
plt.pie(Col_U, labels = Col_U.index, autopct = '%1.1f%%', colors = plt.cm.Pastel1.colors, wedgeprops={'width': 0.5})
plt.title('Exercise Frequency')
plt.axis('equal')
plt.show()

# %% [markdown]
# 19. Sleep hours distribution

# %%
plt.figure(figsize=(15, 6))
sns.histplot(data['sleep_hours'], bins=20, kde=True, color='orchid')
plt.title('Sleep Hours Distribution')
plt.xlabel('Sleep Hours')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 20. BMI Distribution

# %%
plt.figure(figsize=(15, 6))
sns.histplot(data['bmi'], bins=20, kde=True, color='gold')
plt.title('BMI Distribution')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 21. Social Support (Bar Chart)

# %%
plt.figure(figsize=(15, 6))
sns.countplot(y = 'social_support', data = data, palette = 'Paired')
plt.title('Social Support Distribution')
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
